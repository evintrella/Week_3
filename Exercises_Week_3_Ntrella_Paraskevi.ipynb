# %%
import math

# %%
from google.colab import drive

drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datajour-gr/DataJournalism/main/Bachelor%20Lessons%202023/Lesson%203/countries.csv")
df
# Out:
#                  country   continent  gdp_per_capita  life_expectancy  \
# 0            Afghanistan        Asia             663           54.863
# 1                Albania      Europe            4195           74.200
# 2                Algeria      Africa            5098           68.963
# 3                 Angola      Africa            2446           45.234
# 4    Antigua and Barbuda  N. America           12738           73.544
# ..                   ...         ...             ...              ...
# 183              Vietnam        Asia            1577           73.777
# 184   West Bank and Gaza        Asia            7586           70.929
# 185          Yemen, Rep.        Asia            2217           60.404
# 186               Zambia      Africa            1035           41.802
# 187             Zimbabwe      Africa             745           43.976
#
#      population
# 0      22856302
# 1       3071856
# 2      30533827
# 3      13926373
# 4         77656
# ..          ...
# 183    78758010
# 184     3198560
# 185    17723186
# 186    10201562
# 187    12509477
#
# [188 rows x 5 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Άσκηση 1: Πώς θα μπορούσαμε να γράψουμε τον κώδικα σε ένα κελί ώστε να μας δώσει στο output ταυτόχρονα το shape και το head?

# %%
df.shape, df.head()
# Out:
# ((188, 5),
#                 country   continent  gdp_per_capita  life_expectancy  \
#  0          Afghanistan        Asia             663           54.863
#  1              Albania      Europe            4195           74.200
#  2              Algeria      Africa            5098           68.963
#  3               Angola      Africa            2446           45.234
#  4  Antigua and Barbuda  N. America           12738           73.544
#
#     population
#  0    22856302
#  1     3071856
#  2    30533827
#  3    13926373
#  4       77656  )

# %% [markdown]
# Άσκηση 2: Βρείτε τις ελάχιστες τιμές του προσδόκιμου ζωής και του κατά κεφαλή ΑΕΠ στρογγυλοποιημένες σε 1 δεκαδικό

# %%
df[["life_expectancy","gdp_per_capita"]].min().round(1)
# Out:
# life_expectancy     38.1
# gdp_per_capita     292.0
# dtype: float64

# %% [markdown]
# 'Ασκηση 3:Μετατρέψτε το προσδόκιμο ζωής σε ακέραιο και φτιάξτε τον πίνακα συχνοτήτων του

# %%
df.life_expectancy.astype(int).value_counts()
# Out:
# 70    17
# 73    11
# 71    11
# 78    10
# 74     9
# 76     9
# 67     9
# 79     8
# 72     8
# 77     7
# 62     7
# 69     6
# 63     6
# 46     5
# 50     5
# 68     5
# 57     5
# 55     4
# 66     4
# 47     4
# 52     4
# 59     3
# 75     3
# 51     3
# 48     3
# 65     3
# 43     2
# 56     2
# 60     2
# 49     2
# 58     2
# 61     1
# 53     1
# 38     1
# 54     1
# 64     1
# 81     1
# 80     1
# 45     1
# 41     1
# Name: life_expectancy, dtype: int64

# %% [markdown]
# 'Ασκηση 4:Ταξινομήστε το dataframe ως προς το gdp_per_capita σε φθίνουσα σειρά και εμφανίστε ένα dataframe μόνο με τις στήλες country και gdp_per_capita

# %%
df.sort_values(["gdp_per_capita"], ascending= False)[["gdp_per_capita", "country"]]
# Out:
#      gdp_per_capita           country
# 99            63924        Luxembourg
# 135           60394             Qatar
# 23            48020            Brunei
# 125           43174            Norway
# 178           39758     United States
# ..              ...               ...
# 96              519           Liberia
# 147             517      Sierra Leone
# 54              512          Ethiopia
# 26              443           Burundi
# 37              292  Congo, Dem. Rep.
#
# [188 rows x 2 columns]

# %% [markdown]
# Άσκηση 5:
#
# Βρείτε τις χώρες όπου το προσδόκιμο ζωής είναι μεγαλύτερο από το μέσο όρο και εμφανίστε ένα dataframe με τις στήλες country, life_expectancy και gdp_per_capita, ταξινομημένο ως προς το κατά κεφαλή gdp_per_capita με φθίνουσα σειρά
#
# (κάνετε όλα αυτά σε μια γραμμή κώδικα)

# %%
df.sort_values(["gdp_per_capita"], ascending= False)[df["life_expectancy"]>df["life_expectancy"].mean()][["country","life_expectancy" ,"gdp_per_capita"]]
# Out:
# <ipython-input-13-b33f713f8279>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.sort_values(["gdp_per_capita"], ascending= False)[df["life_expectancy"]>df["life_expectancy"].mean()][["country","life_expectancy" ,"gdp_per_capita"]]
#            country  life_expectancy  gdp_per_capita
# 99      Luxembourg           77.820           63924
# 135          Qatar           76.680           60394
# 23          Brunei           75.927           48020
# 125         Norway           78.760           43174
# 178  United States           76.800           39758
# ..             ...              ...             ...
# 30      Cape Verde           69.835            2291
# 6          Armenia           71.494            2114
# 112        Moldova           67.007            1692
# 180     Uzbekistan           66.999            1635
# 183        Vietnam           73.777            1577
#
# [118 rows x 3 columns]

# %% [markdown]
# Άσκηση 6:
#
# Βρείτε τις χώρες της Ασίας όπου το προσδόκιμο ζωής είναι κάτω από 64 και ταξινομήστε τες σε αύξουσα σειρά (ως προς το όνομα των χωρών). Εμφανίστε τις 5 πρώτες.

# %%
df[(df['continent']=='Asia') & (df['life_expectancy']<64)].sort_values('country').head() #αν θέλουμε να φαίνονται όλα τα στοιχεία
# Out:
#         country continent  gdp_per_capita  life_expectancy  population
# 0   Afghanistan      Asia             663           54.863    22856302
# 18       Bhutan      Asia            2922           60.307      571262
# 27     Cambodia      Asia             982           62.030    12446949
# 75        India      Asia            1648           62.129  1053898107
# 85   Kazakhstan      Asia            5366           63.513    14956694

# %%
df[(df['continent']=='Asia') & (df['life_expectancy']<64)].sort_values('country').head()[['country','life_expectancy']]
#αν θέλουμε να μας εμφανίσει μόνο τις χώρες και το προσδόκιμο ζωής
# Out:
#         country  life_expectancy
# 0   Afghanistan           54.863
# 18       Bhutan           60.307
# 27     Cambodia           62.030
# 75        India           62.129
# 85   Kazakhstan           63.513

# %% [markdown]
# Άσκηση 7: Βρείτε τη χώρα με το μικρότερο προσδόκιμο ζωής [min()]

# %%
df[df['life_expectancy'] == df['life_expectancy'].min()][['country', 'life_expectancy']]  #εάν θέλουμε να καταγράφεται και η χώρα και το προσδόκιμο
# Out:
#           country  life_expectancy
# 147  Sierra Leone           38.123

# %%
df[df['life_expectancy'] == df['life_expectancy'].min()]['country']  #εάν θέλουμε να καταγράφεται μόνο η χώρα
# Out:
# 147    Sierra Leone
# Name: country, dtype: object

# %% [markdown]
# Άσκηση 8: Βρείτε τις χώρες όπου το προσδόκιμο ζωής είναι από ένα χρόνο κάτω έως ένα χρόνο πάνω του μέσου όρου

# %%
df[(df['life_expectancy']>=df['life_expectancy'].mean()-1) & (df['life_expectancy']<=df['life_expectancy'].mean()+1)][['country','life_expectancy']]
# Out:
#                    country  life_expectancy
# 9               Azerbaijan           66.851
# 64               Greenland           67.030
# 76               Indonesia           67.289
# 91              Kyrgyzstan           66.232
# 111  Micronesia, Fed. Sts.           67.300
# 112                Moldova           67.007
# 132            Philippines           66.774
# 180             Uzbekistan           66.999
# 181                Vanuatu           67.438

# %% [markdown]
# Άσκηση 9:
#
# Βρείτε το συνολικό πληθυσμό (sum) σε κάθε ήπειρο

# %%
df.groupby('continent')['population'].sum()
# Out:
# continent
# Africa         809892820
# Asia          3849172861
# Europe         596440013
# N. America     481999240
# Oceania         30272328
# S. America     347265096
# Name: population, dtype: int64

# %% [markdown]
# Άσκηση 10:
#
# Βρείτε σε ποιες ηπείρους ο μέσος όρος του προσδόκιμου ζωής είναι μικρότερος από 55

# %%
df.groupby('continent')['life_expectancy'].mean()<55

#Άρα ο μέσος όρος του προσδόκιμου ζωής είναι μικρότερος απο 55 στην Αφρική
# Out:
# continent
# Africa         True
# Asia          False
# Europe        False
# N. America    False
# Oceania       False
# S. America    False
# Name: life_expectancy, dtype: bool

# %% [markdown]
# Άσκηση 11:
#
# Βρείτε πόσες χώρες υπάρχουν σε κάθε ήπειρο (count) και ταξινομήστε το αποτέλεσμα σε φθίνουσα σειρά

# %%
df.sort_values(['country'], ascending=False).groupby('continent')['country'].count()
# Out:
# continent
# Africa        54
# Asia          48
# Europe        42
# N. America    22
# Oceania       10
# S. America    12
# Name: country, dtype: int64

# %% [markdown]
# Άσκηση 12:
#
# Ακαθάριστο Εγχώριο Προϊόν (ΑΕΠ / GDP) είναι το σύνολο των προϊόντων, υλικών και άυλων, που παράχθηκαν μέσα στην επικράτεια μιας χώρας σε διάστημα ενός έτους, εκφρασμένο σε χρηματικές μονάδες, ακόμα και αν μέρος αυτού παράχθηκε από παραγωγικές μονάδες που ανήκουν σε κατοίκους του εξωτερικού.
#
# Το κατά κεφαλή ΑΕΠ (gdp per capita) είναι το μέρος του ΑΕΠ μιας χώρας που θεωρητικά αναλογεί σε κάθε της κάτοικο. Προκύπτει από τη σχέση: gdp_per_capita = GDP / population.
#
# Στο dataframe έχουμε το gdp_per_capita και το population.
#
# Βρείτε το ΑΕΠ κάθε χώρας και αποθηκεύστε το στο dataframe σε μια νέα στήλη με όνομα "gdp".

# %%
df['gdp'] = df['gdp_per_capita']/df['population']

# %%
df
# Out:
#                  country   continent  gdp_per_capita  life_expectancy  \
# 0            Afghanistan        Asia             663           54.863
# 1                Albania      Europe            4195           74.200
# 2                Algeria      Africa            5098           68.963
# 3                 Angola      Africa            2446           45.234
# 4    Antigua and Barbuda  N. America           12738           73.544
# ..                   ...         ...             ...              ...
# 183              Vietnam        Asia            1577           73.777
# 184   West Bank and Gaza        Asia            7586           70.929
# 185          Yemen, Rep.        Asia            2217           60.404
# 186               Zambia      Africa            1035           41.802
# 187             Zimbabwe      Africa             745           43.976
#
#      population       gdp
# 0      22856302  0.000029
# 1       3071856  0.001366
# 2      30533827  0.000167
# 3      13926373  0.000176
# 4         77656  0.164031
# ..          ...       ...
# 183    78758010  0.000020
# 184     3198560  0.002372
# 185    17723186  0.000125
# 186    10201562  0.000101
# 187    12509477  0.000060
#
# [188 rows x 6 columns]

# %% [markdown]
# Άσκηση 13:
# Βρείτε το μ.ο. του κατά κεφαλή ΑΕΠ ανά ήπειρο και φτιάξτε ένα γράφημμα πίτας (pie chart).

# %%
df.groupby('continent')['gdp_per_capita'].mean().plot(kind='pie')
# Out:
# <Axes: ylabel='gdp_per_capita'>
